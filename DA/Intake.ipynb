# %%
import pandas as pd
import os
# 폴더 안의 파일 확인
os.listdir('/Users/jaekim/Desktop/C-5.Project/Ingestion')
# Out:
# ['식품군별 평균 섭취량 - 연령층별(전체)_2012.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2013.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2011.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2010.xls',
#  '.DS_Store',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2014.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2015.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2017.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2016.xls',
#  '식품군별_평균_섭취량_연령층별(여성)_종합.csv',
#  '식품군별_평균_섭취량_연령층별(남자)_종합.csv',
#  '.ipynb_checkpoints',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2018.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2019.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2009.xls',
#  '식품군별 평균 섭취량 - 연령층별(전체)_2020.xls',
# ...

# %%
df1 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2008.xls')
df2 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2009.xls')
df3 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2010.xls')
df4 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2011.xls')
df5 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2012.xls')
df6 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2013.xls')
df7 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2014.xls')
df8 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2015.xls')
df9 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2016.xls')
df10 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2017.xls')
df11 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2018.xls')
df12 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2019.xls')
df13 = pd.read_excel('/Users/jaekim/Desktop/C-5.Project/Ingestion/식품군별 평균 섭취량 - 연령층별(전체)_2020.xls')

# %%
df1['연도'] = 2008
df2['연도'] = 2009
df3['연도'] = 2010
df4['연도'] = 2011
df5['연도'] = 2012
df6['연도'] = 2013
df7['연도'] = 2014
df8['연도'] = 2015
df9['연도'] = 2016
df10['연도'] = 2017
df11['연도'] = 2018
df12['연도'] = 2019
df13['연도'] = 2020

# %%
result = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13])
result
# Out:
#         식품군＼연령(세)    전체 평균  전체 표준오차  1-2 평균  1-2 표준오차   3-5 평균  3-5 표준오차  \
# 0       곡류 및 그 제품   287.94     2.56  136.76      4.31   196.89      4.60
# 1        감자 및 전분류    35.86     1.63   20.76      2.98    23.48      2.01
# 2       당류 및 그 제품     7.49     0.21    2.79      0.48     4.31      0.40
# 3       두류 및 그 제품    36.65     1.16   50.71      8.04    26.48      3.33
# 4      종실류 및 그 제품     2.93     0.21    2.80      1.53     1.94      0.76
# ..            ...      ...      ...     ...       ...      ...       ...
# 20        기타(동물성)     0.54     0.10    0.76      0.07     0.00      0.00
# 21        동물성 식품계   348.72     5.73  314.81     23.76   381.09     19.73
# 22             총계  1475.73    15.68  830.18     29.73  1033.57     29.12
# 23  식물성식품 섭취비율(%)    76.07     0.27   60.93      2.55    63.47      1.36
# 24  동물성식품 섭취비율(%)    23.93     0.27   39.07      2.55    36.53      1.36
#
#     6-11 평균  6-11 표준오차  12-18 평균  12-18 표준오차  19-29 평균  19-29 표준오차  30-49 평균  \
# ...

# %%
# 데이터 타입 확인
result.dtypes
# Out:
# 식품군＼연령(세)      object
# 전체 평균         float64
# 전체 표준오차       float64
# 1-2 평균        float64
# 1-2 표준오차      float64
# 3-5 평균        float64
# 3-5 표준오차      float64
# 6-11 평균       float64
# 6-11 표준오차     float64
# 12-18 평균      float64
# 12-18 표준오차    float64
# 19-29 평균      float64
# 19-29 표준오차    float64
# 30-49 평균      float64
# 30-49 표준오차    float64
# 50-64 평균      float64
# 50-64 표준오차    float64
# ≥ 65 평균       float64
# ≥ 65 표준오차     float64
# 연도              int64
# dtype: object

# %%
# 정보 확인
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 0 to 24
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   식품군＼연령(세)   325 non-null    object
#  1   전체 평균       325 non-null    float64
#  2   전체 표준오차     325 non-null    float64
#  3   1-2 평균      325 non-null    float64
#  4   1-2 표준오차    325 non-null    float64
#  5   3-5 평균      325 non-null    float64
#  6   3-5 표준오차    325 non-null    float64
#  7   6-11 평균     325 non-null    float64
#  8   6-11 표준오차   325 non-null    float64
#  9   12-18 평균    325 non-null    float64
#  10  12-18 표준오차  325 non-null    float64
#  11  19-29 평균    325 non-null    float64
#  12  19-29 표준오차  325 non-null    float64
#  13  30-49 평균    325 non-null    float64
#  14  30-49 표준오차  325 non-null    float64
#  15  50-64 평균    325 non-null    float64
#  16  50-64 표준오차  325 non-null    float64
#  17  ≥ 65 평균     325 non-null    float64
# ...

# %%
result.columns
# Out:
# Index(['식품군＼연령(세)', '전체 평균', '전체 표준오차', '1-2 평균', '1-2 표준오차', '3-5 평균',
#        '3-5 표준오차', '6-11 평균', '6-11 표준오차', '12-18 평균', '12-18 표준오차',
#        '19-29 평균', '19-29 표준오차', '30-49 평균', '30-49 표준오차', '50-64 평균',
#        '50-64 표준오차', '≥ 65 평균', '≥ 65 표준오차', '연도'],
#       dtype='object')

# %%
result = result.drop(['전체 표준오차', '1-2 표준오차', '3-5 표준오차', '6-11 표준오차', '12-18 표준오차',
       '19-29 표준오차', '30-49 표준오차', '50-64 표준오차', '≥ 65 표준오차'], axis = 'columns')
result.head()
# Out:
#     식품군＼연령(세)   전체 평균  1-2 평균  3-5 평균  6-11 평균  12-18 평균  19-29 평균  30-49 평균  \
# 0   곡류 및 그 제품  287.94  136.76  196.89   269.39    325.30    276.61    297.28
# 1    감자 및 전분류   35.86   20.76   23.48    31.14     35.64     33.26     37.34
# 2   당류 및 그 제품    7.49    2.79    4.31     5.63      7.33      8.99      8.86
# 3   두류 및 그 제품   36.65   50.71   26.48    25.66     23.39     38.86     37.41
# 4  종실류 및 그 제품    2.93    2.80    1.94     1.70      2.44      2.57      3.28
#
#    50-64 평균  ≥ 65 평균    연도
# 0    307.14   273.02  2008
# 1     44.71    30.53  2008
# 2      7.37     4.08  2008
# 3     46.64    36.06  2008
# 4      3.73     2.67  2008

# %%
result.columns
# Out:
# Index(['식품군＼연령(세)', '전체 평균', '1-2 평균', '3-5 평균', '6-11 평균', '12-18 평균',
#        '19-29 평균', '30-49 평균', '50-64 평균', '≥ 65 평균', '연도'],
#       dtype='object')

# %%
result = result.T
result
# Out:
#                   0         1          2          3           4       5   \
# 식품군＼연령(세)  곡류 및 그 제품  감자 및 전분류  당류 및 그 제품  두류 및 그 제품  종실류 및 그 제품     채소류
# 전체 평균         287.94     35.86       7.49      36.65        2.93  301.47
# 1-2 평균        136.76     20.76       2.79      50.71         2.8   65.35
# 3-5 평균        196.89     23.48       4.31      26.48        1.94   98.06
# 6-11 평균       269.39     31.14       5.63      25.66         1.7  173.31
# 12-18 평균       325.3     35.64       7.33      23.39        2.44  225.83
# 19-29 평균      276.61     33.26       8.99      38.86        2.57  275.04
# 30-49 평균      297.28     37.34       8.86      37.41        3.28  365.49
# 50-64 평균      307.14     44.71       7.37      46.64        3.73  367.06
# ≥ 65 평균       273.02     30.53       4.08      36.06        2.67   289.8
# 연도              2008      2008       2008       2008        2008    2008
#
#              6       7     8      9   ...         15     16      17  \
# ...

# %%
# 인덱스 행만 삭제
result.columns = result.iloc[0]
result = result.iloc[1:,].reindex()
result
# Out:
# 식품군＼연령(세) 곡류 및 그 제품 감자 및 전분류 당류 및 그 제품 두류 및 그 제품 종실류 및 그 제품     채소류   버섯류  \
# 전체 평균        287.94    35.86      7.49     36.65       2.93  301.47   3.8
# 1-2 평균       136.76    20.76      2.79     50.71        2.8   65.35  1.99
# 3-5 평균       196.89    23.48      4.31     26.48       1.94   98.06  2.34
# 6-11 평균      269.39    31.14      5.63     25.66        1.7  173.31  3.05
# 12-18 평균      325.3    35.64      7.33     23.39       2.44  225.83  4.93
# 19-29 평균     276.61    33.26      8.99     38.86       2.57  275.04   4.2
# 30-49 평균     297.28    37.34      8.86     37.41       3.28  365.49   4.2
# 50-64 평균     307.14    44.71      7.37     46.64       3.73  367.06  3.53
# ≥ 65 평균      273.02    30.53      4.08     36.06       2.67   289.8  2.47
# 연도             2008     2008      2008      2008       2008    2008  2008
#
# 식품군＼연령(세)     과실류   해조류    음료류  ... 육류 및 그 제품     난류     어패류 우유류 및 그 제품  \
# 전체 평균      158.89  5.35  66.88  ...    130.29  33.11   88.15      96.24
# ...

# %%
result.columns
# Out:
# Index(['곡류 및 그 제품', '감자 및 전분류', '당류 및 그 제품', '두류 및 그 제품', '종실류 및 그 제품', '채소류',
#        '버섯류', '과실류', '해조류', '음료류',
#        ...
#        '육류 및 그 제품', '난류', '어패류', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)', length=325)

# %%
df1 = result['곡류 및 그 제품']
df = result.drop(['곡류 및 그 제품'], axis=1)
df1 = df1.T
df1 = df1.set_index('연도')
df1.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df2 = result['감자 및 전분류']
df = df.drop(['감자 및 전분류'], axis=1)
df2 = df2.T
df2 = df2.set_index('연도')
df2.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df3 = result['당류 및 그 제품']
df = df.drop(['당류 및 그 제품'], axis=1)
df3 = df3.T
df3 = df3.set_index('연도')
df3.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['두류 및 그 제품', '종실류 및 그 제품', '채소류', '버섯류', '과실류', '해조류', '음료류', '주류',
#        '조미료류', '유지류(식물성)',
#        ...
#        '육류 및 그 제품', '난류', '어패류', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)', length=286)

# %%
df4 = result['두류 및 그 제품']
df = df.drop(['두류 및 그 제품'], axis=1)
df4 = df4.T
df4 = df4.set_index('연도')
df4.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df5 = result['종실류 및 그 제품']
df = df.drop(['종실류 및 그 제품'], axis=1)
df5 = df5.T
df5 = df5.set_index('연도')
df5.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df6 = result['채소류']
df = df.drop(['채소류'], axis=1)
df6 = df6.T
df6 = df6.set_index('연도')
df6.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['버섯류', '과실류', '해조류', '음료류', '주류', '조미료류', '유지류(식물성)', '기타(식물성)',
#        '식물성 식품계', '육류 및 그 제품',
#        ...
#        '육류 및 그 제품', '난류', '어패류', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)', length=247)

# %%
df7 = result['버섯류']
df = df.drop(['버섯류'], axis=1)
df7 = df7.T
df7 = df7.set_index('연도')
df7.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df8 = result['과실류']
df = df.drop(['과실류'], axis=1)
df8 = df8.T
df8 = df8.set_index('연도')
df8.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df9 = result['해조류']
df = df.drop(['해조류'], axis=1)
df9 = df9.T
df9 = df9.set_index('연도')
df9.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df10 = result['음료류']
df = df.drop(['음료류'], axis=1)
df10 = df10.T
df10 = df10.set_index('연도')
df10.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['주류', '조미료류', '유지류(식물성)', '기타(식물성)', '식물성 식품계', '육류 및 그 제품', '난류',
#        '어패류', '우유류 및 그 제품', '유지류(동물성)',
#        ...
#        '육류 및 그 제품', '난류', '어패류', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)', length=195)

# %%
df11 = result['주류']
df = df.drop(['주류'], axis=1)
df11 = df11.T
df11 = df11.set_index('연도')
df11.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df12 = result['조미료류']
df = df.drop(['조미료류'], axis=1)
df12 = df12.T
df12 = df12.set_index('연도')
df12.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df13 = result['유지류(식물성)']
df = df.drop(['유지류(식물성)'], axis=1)
df13 = df13.T
df13 = df13.set_index('연도')
df13.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['기타(식물성)', '식물성 식품계', '육류 및 그 제품', '난류', '어패류', '우유류 및 그 제품',
#        '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계',
#        ...
#        '육류 및 그 제품', '난류', '어패류', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)', length=159)

# %%
df14 = result['기타(식물성)']
df = df.drop(['기타(식물성)'], axis=1)
df14 = df14.T
df14 = df14.set_index('연도')
df14.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df15 = result['식물성 식품계']
df = df.drop(['식물성 식품계'], axis=1)
df15 = df15.T
df15 = df15.set_index('연도')
df15.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df16 = result['육류 및 그 제품']
df = df.drop(['육류 및 그 제품'], axis=1)
df16 = df16.T
df16 = df16.set_index('연도')
df16.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df17 = result['난류']
df = df.drop(['난류'], axis=1)
df17 = df17.T
df17 = df17.set_index('연도')
df17.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df18 = result['어패류']
df = df.drop(['어패류'], axis=1)
df18 = df18.T
df18 = df18.set_index('연도')
df18.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['우유류 및 그 제품', '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '우유류 및 그 제품',
#        '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '우유류 및 그 제품',
#        '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '우유류 및 그 제품', '유지류(동물성)', '기타(동물성)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '유지(식물성)', '유류 및 그 제품', '유지(동물성)',
#        '기타(동물성)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '유지(식물성)',
#        '유류 및 그 제품', '유지(동물성)', '기타(동물성)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
# ...

# %%
df19 = result['우유류 및 그 제품']
df = df.drop(['우유류 및 그 제품'], axis=1)
df19 = df19.T
df19 = df19.set_index('연도')
df19.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df20 = result['유지류(동물성)']
df = df.drop(['유지류(동물성)'], axis=1)
df20 = df20.T
df20 = df20.set_index('연도')
df20.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df21 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df21 = df21.T
df21 = df21.set_index('연도')
df21.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '유지(식물성)', '유류 및 그 제품', '유지(동물성)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '유지(식물성)', '유류 및 그 제품', '유지(동물성)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '유지(식물성)', '유류 및 그 제품', '유지(동물성)',
#        '동물성 식품계', '총계', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성 식품계', '총계',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성 식품계', '총계', '식물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)')

# %%
df22 = result['동물성 식품계']
df = df.drop(['동물성 식품계'], axis=1)
df22 = df22.T
df22 = df22.set_index('연도')
df22.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df23 = result['총계']
df = df.drop(['총계'], axis=1)
df23 = df23.T
df23 = df23.set_index('연도')
df23.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '유지(식물성)', '유류 및 그 제품', '유지(동물성)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '유지(식물성)', '유류 및 그 제품', '유지(동물성)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '유지(식물성)', '유류 및 그 제품', '유지(동물성)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '식물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)')

# %%
df24 = result['식물성식품 섭취비율(%)']
df = df.drop(['식물성식품 섭취비율(%)'], axis=1)
df24 = df24.T
df24 = df24.set_index('연도')
df24.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)',
#        '유지(식물성)', '유류 및 그 제품', '유지(동물성)', '동물성식품 섭취비율(%)', '유지(식물성)',
#        '유류 및 그 제품', '유지(동물성)', '동물성식품 섭취비율(%)', '유지(식물성)', '유류 및 그 제품',
#        '유지(동물성)', '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)', '동물성식품 섭취비율(%)'],
#       dtype='object', name='식품군＼연령(세)')

# %%
df25 = result['동물성식품 섭취비율(%)']
df = df.drop(['동물성식품 섭취비율(%)'], axis=1)
df25 = df25.T
df25 = df25.set_index('연도')
df25.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df26 = result['유지(식물성)']
df = df.drop(['유지(식물성)'], axis=1)
df26 = df26.T
df26 = df26.set_index('연도')
df26.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['유류 및 그 제품', '유지(동물성)', '유류 및 그 제품', '유지(동물성)', '유류 및 그 제품', '유지(동물성)'], dtype='object', name='식품군＼연령(세)')

# %%
df27 = result['유류 및 그 제품']
df = df.drop(['유류 및 그 제품'], axis=1)
df27 = df27.T
df27 = df27.set_index('연도')
df27.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index(['유지(동물성)', '유지(동물성)', '유지(동물성)'], dtype='object', name='식품군＼연령(세)')

# %%
df28 = result['유지(동물성)']
df = df.drop(['유지(동물성)'], axis=1)
df28 = df28.T
df28 = df28.set_index('연도')
df28.plot()
# Out:
# /Users/jaekim/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='연도'>

# %%
df.columns
# Out:
# Index([], dtype='object', name='식품군＼연령(세)')

# %%
df29 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df29 = df29.T
df29 = df29.set_index('연도')
df29.plot()
# Out:
# Index(['주류', '주류', '주류', '주류', '주류', '주류', '주류', '주류', '주류', '주류',
#        ...
#        '감자 및 전분류', '감자 및 전분류', '감자 및 전분류', '감자 및 전분류', '감자 및 전분류', '감자 및 전분류',
#        '감자 및 전분류', '감자 및 전분류', '감자 및 전분류', '감자 및 전분류'],
#       dtype='object', name='식품군＼연령(세)', length=286)

# %%
df30 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df30 = df30.T
df30 = df30.set_index('연도')
df30.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df = df.set_index('연도',inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'set_index'

# %%
df31 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df31 = df31.T
df31 = df31.set_index('연도')
df31.plot()

# %%
df32 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df32 = df32.T
df32 = df32.set_index('연도')
df32.plot()

# %%
df33 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df33 = df33.T
df33 = df33.set_index('연도')
df33.plot()

# %%
df34 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df34 = df34.T
df34 = df34.set_index('연도')
df34.plot()

# %%
df35 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df35 = df35.T
df35 = df35.set_index('연도')
df35.plot()

# %%
df36 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df36 = df36.T
df36 = df36.set_index('연도')
df36.plot()

# %%
df37 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df37 = df37.T
df37 = df37.set_index('연도')
df37.plot()

# %%
df38 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df38 = df38.T
df38 = df38.set_index('연도')
df38.plot()

# %%
df39 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df39 = df39.T
df39 = df39.set_index('연도')
df39.plot()

# %%
df40 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df40 = df40.T
df40 = df40.set_index('연도')
df40.plot()

# %%
df41 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df41 = df41.T
df41 = df41.set_index('연도')
df41.plot()

# %%
df42 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df42 = df42.T
df42 = df42.set_index('연도')
df42.plot()

# %%
df43 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df43 = df43.T
df43 = df43.set_index('연도')
df43.plot()

# %%
df44 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df44 = df44.T
df44 = df44.set_index('연도')
df44.plot()

# %%
df45 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df45 = df45.T
df45 = df45.set_index('연도')
df45.plot()

# %%
df46 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df46 = df46.T
df46 = df46.set_index('연도')
df46.plot()

# %%
df47 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df47 = df47.T
df47 = df47.set_index('연도')
df47.plot()

# %%
df48 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df48 = df48.T
df48 = df48.set_index('연도')
df48.plot()

# %%
df49 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df49 = df49.T
df49 = df49.set_index('연도')
df49.plot()

# %%
df50 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df50 = df50.T
df50 = df50.set_index('연도')
df50.plot()

# %%
df51 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df51 = df51.T
df51 = df51.set_index('연도')
df51.plot()

# %%
df52 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df52 = df52.T
df52 = df52.set_index('연도')
df52.plot()

# %%
df53 = result['기타(동물성)']
df = df.drop(['기타(동물성)'], axis=1)
df53 = df53.T
df53 = df53.set_index('연도')
df53.plot()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰드
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
